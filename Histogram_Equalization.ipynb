# %% [markdown]
# <a href="https://colab.research.google.com/github/deryabol/Image_Processing/blob/main/Histogram_Equalization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import cv2 as cv

# %%
from matplotlib import pyplot as plt

# %%
img =cv.imread('brain.jpg',0)

# %%
hist,bins=np.histogram(img.flatten(),256,[0,256])

# %%
cdf=hist.cumsum()

# %%
cdf_normalized=cdf=cdf*float(hist.max())/cdf.max()

# %%
plt.plot(cdf_normalized, color='b')

# %%
plt.hist(img.flatten(),256,[0,256],color='r')
# Out:
# (array([2.2000e+01, 4.7700e+02, 4.1670e+03, 7.6020e+03, 1.8012e+04,
#         1.5691e+04, 1.3634e+04, 2.1186e+04, 1.8172e+04, 1.3498e+04,
#         1.2293e+04, 1.6761e+04, 1.8542e+04, 2.0117e+04, 1.9263e+04,
#         1.8415e+04, 1.8215e+04, 1.0170e+04, 1.2324e+04, 1.4839e+04,
#         1.5127e+04, 1.3059e+04, 1.1106e+04, 1.0370e+04, 6.9740e+03,
#         7.0180e+03, 6.9510e+03, 8.2160e+03, 8.1780e+03, 8.4450e+03,
#         7.7440e+03, 5.6790e+03, 7.1540e+03, 8.0400e+03, 1.0775e+04,
#         1.0343e+04, 1.0063e+04, 9.6880e+03, 6.4070e+03, 5.9530e+03,
#         6.6990e+03, 7.4490e+03, 8.0640e+03, 8.4320e+03, 6.5930e+03,
#         5.6420e+03, 4.7160e+03, 4.9060e+03, 6.0500e+03, 6.4960e+03,
#         6.9200e+03, 5.9910e+03, 5.0330e+03, 4.8680e+03, 5.6190e+03,
#         6.4170e+03, 7.4620e+03, 7.6050e+03, 6.4480e+03, 5.1660e+03,
#         5.2280e+03, 5.4410e+03, 5.8400e+03, 6.0880e+03, 6.2890e+03,
#         5.7530e+03, 4.5140e+03, 3.8220e+03, 3.9340e+03, 4.3750e+03,
# ...

# %%
plt.xlim([0,256])
# Out:
# (0.0, 256.0)

# %%
plt.legend(('cdf','histogram'),loc='upper left')

# %%
plt.show()
